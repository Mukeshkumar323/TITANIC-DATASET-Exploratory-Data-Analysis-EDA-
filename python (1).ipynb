# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("test 1.csv")
df.head()
df.info()
df.describe(include='all')
df.isnull().sum()
df.duplicated().sum()

# Original code had KeyError: 'Region'. Replaced with an existing categorical column 'Sex'.
df["Sex"].value_counts()

# Replaced 'Category' with another existing categorical column 'Embarked'
df["Embarked"].value_counts()

# Fixed KeyError: 'Customer_Name' by using the correct column name 'Name'
df["Name"].value_counts().head()
sns.pairplot(df.select_dtypes(include='number'))
plt.show()
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(),
            annot=True,
            cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
df.select_dtypes(include='number').hist(figsize=(12,8))
plt.tight_layout()
plt.show()


numeric_cols = [col for col in df.select_dtypes(include='number').columns if df[col].count() >= 2]

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# The following lines were causing an IndentationError and also referred to non-existent columns.
# They have been commented out.
# plt.figure(figsize=(8,5))
# sns.scatterplot(data=df,
#                 x="Gross_Sales",
#                 y="Net_Sales")
# # plt.title("Gross Sales vs Net Sales")
# # plt.show()
# #
# # plt.figure(figsize=(8,5))
# # sns.countplot(data=df,
# #               x="Region")
# # plt.xticks(rotation=45)
# # plt.show()
df.to_csv("cleaned_dataset.csv", index=False)
from google.colab import files
files.download("cleaned_dataset.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Passenger ID      418 non-null    int64
#  1   Class             418 non-null    int64
#  2   Name              418 non-null    object
#  3   Sex               418 non-null    object
#  4   Age               418 non-null    float64
#  5   Sibs              418 non-null    int64
#  6   Parch             418 non-null    int64
#  7   Kelly, Mr. James  418 non-null    object
#  8   Fare              418 non-null    object
#  9   Cabin             418 non-null    object
#  10  Embarked          418 non-null    object
#  11  Unnamed: 11       0 non-null      float64
#  12  Unnamed: 12       1 non-null      float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 42.6+ KB

# %% [markdown]
# # New Section
